# %%
# Once you've installed NumPy you can import it as a library:
import numpy as np
# Out:
# Running cells with 'Python 3.12.0' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Ishaan Rastogi/AppData/Local/Programs/Python/Python312/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# NumPy arrays are the main way we will use Numpy throughout the course. Numpy arrays essentially come in two flavors: vectors and matrices.
# Vectors are strictly 1-d arrays and matrices are 2-d (but you should note a matrix can still have only one row or one column).

# %%
# Creating NumPy Arrays

# 1. From a Python List

my_list = [1,2,3]
print(my_list)
# Out:
# Running cells with 'Python 3.12.0' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Ishaan Rastogi/AppData/Local/Programs/Python/Python312/python.exe" -m pip install ipykernel -U --user --force-reinstall'
